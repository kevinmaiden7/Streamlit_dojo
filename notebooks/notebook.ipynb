# %%
import pandas as pd

# %%
df = pd.read_csv("../data/bank_reviews.csv")
df.head(5)
# Out:
#         author          date    address       bank  rating  \
# 0  AMRENDRA  T  Mar 21, 2020  New delhi        SBI     4.0
# 1       BISHWA  Mar 20, 2020    Kolkata        SBI     5.0
# 2      SANTOSH  Mar 20, 2020    Hooghly  Axis Bank     5.0
# 3      MAHADEV  Mar 20, 2020       Pune  HDFC Bank     5.0
# 4            R  Mar 20, 2020  Bangalore     review     5.0
#
#   review_title_by_user                                             review  \
# 0        "Best saving"  State Bank Of India is located nearby in our a...
# 1       "Good service"  I have my salary account in SBI, when I applie...
# 2  "Excellent Service"  I am using Axis bank saving account for the  p...
# 3  "Excellent service"  I have my salary bank account in HDFC bank for...
# 4       "Good account"  Close to around 10 years, I am holding this Co...
#
#                                           bank_image rating_title_by_user  \
# 0  https://static.bankbazaar.com/images/common/ba...               Great!
# ...

# %%
list(df.columns)
# Out:
# ['author',
#  'date',
#  'address',
#  'bank',
#  'rating',
#  'review_title_by_user',
#  'review',
#  'bank_image',
#  'rating_title_by_user',
#  'useful_count']

# %%
df.shape
# Out:
# (1000, 10)

# %%
df[['author', 'date']]
# Out:
#           author          date
# 0    AMRENDRA  T  Mar 21, 2020
# 1         BISHWA  Mar 20, 2020
# 2        SANTOSH  Mar 20, 2020
# 3        MAHADEV  Mar 20, 2020
# 4              R  Mar 20, 2020
# ..           ...           ...
# 995          A L  Nov 26, 2019
# 996          A L  Nov 26, 2019
# 997      ANONYMS  Nov 26, 2019
# 998    SAJJANOJU  Nov 26, 2019
# 999      ANONYMS  Nov 26, 2019
#
# [1000 rows x 2 columns]

# %%
df.iloc[:,0:3]
# Out:
#           author          date    address
# 0    AMRENDRA  T  Mar 21, 2020  New delhi
# 1         BISHWA  Mar 20, 2020    Kolkata
# 2        SANTOSH  Mar 20, 2020    Hooghly
# 3        MAHADEV  Mar 20, 2020       Pune
# 4              R  Mar 20, 2020  Bangalore
# ..           ...           ...        ...
# 995          A L  Nov 26, 2019  Ernakulam
# 996          A L  Nov 26, 2019  Ernakulam
# 997      ANONYMS  Nov 26, 2019  Bangalore
# 998    SAJJANOJU  Nov 26, 2019  Hyderabad
# 999      ANONYMS  Nov 26, 2019    Kolkata
#
# [1000 rows x 3 columns]
